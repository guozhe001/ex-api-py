# %%
from binance.client import Client

from config import config_util
from constant import constant

key, secret = config_util.get_api_key_secret(exchange=constant.EXCHANGE_BINANCE)
print("key={}, secret={}".format(key, secret))
client = Client(key, secret)
depth = client.get_order_book(symbol='BNBBTC')
# print(type(depth))
# print(depth)
for item in depth.items():
    print(type(item))
    print(item)


tickers = client.get_all_tickers()
print(tickers)
# Out:
# key=FC9TKXJD5t03hWSrWRyYwRSs0RihmSCshocKKhdgfOIuZ7wAHiwcUKI0vZ2L4rHc, secret=ytmRyH5g07PmhPVidGNOlqwr6mCd88nCY6cDDjjYl6nC0mlhhc7dUK6UpmNSKjDl
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     435             try:
# --> 436                 cnx.do_handshake()
#     437             except OpenSSL.SSL.WantReadError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# ...

# %%
for name, item in depth.items():
    print(name)
    print(type(item))
    print(item)
# Out:
# lastUpdateId
# <class 'int'>
# 1822161530
# bids
# <class 'list'>
# ...

# %%
'2021-04-22 10:00:00,0.12338,0.12359,0.11993,0.12265,4740589.499812,2021-04-22 11:00:00,,,,'
# Out:
# '2021-04-22 10:00:00,0.12338,0.12359,0.11993,0.12265,4740589.499812,2021-04-22 11:00:00,,,,'

# %%
from binance.client import Client

from config import config_util
from constant import constant

key, secret = config_util.get_api_key_secret(exchange=constant.EXCHANGE_BINANCE)

# print("key={}, secret={}".format(key, secret))
# client = Client(key, secret)
# depth = client.get_order_book(symbol='BNBBTC')
# # print(type(depth))
# # print(depth)
# for item in depth.items():
#     print(type(item))
#     print(item)

tickers = client.get_all_tickers()
# print(tickers)

# print(type(tickers))

for t in tickers:
    print(t)
# Out:
# {'symbol': 'ETHBTC', 'price': '0.05031100'}
# {'symbol': 'LTCBTC', 'price': '0.00472200'}
# {'symbol': 'BNBBTC', 'price': '0.01065000'}
# {'symbol': 'NEOBTC', 'price': '0.00169500'}
# {'symbol': 'QTUMETH', 'price': '0.00524200'}
# {'symbol': 'EOSETH', 'price': '0.00216200'}
# {'symbol': 'SNTETH', 'price': '0.00005960'}
# {'symbol': 'BNTETH', 'price': '0.00243000'}
# {'symbol': 'BCCBTC', 'price': '0.07908100'}
# {'symbol': 'GASBTC', 'price': '0.00027230'}
# {'symbol': 'BNBETH', 'price': '0.21147000'}
# {'symbol': 'BTCUSDT', 'price': '53927.01000000'}
# {'symbol': 'ETHUSDT', 'price': '2713.15000000'}
# {'symbol': 'HSRBTC', 'price': '0.00041400'}
# {'symbol': 'OAXETH', 'price': '0.00017780'}
# {'symbol': 'DNTETH', 'price': '0.00002801'}
# {'symbol': 'MCOETH', 'price': '0.00577200'}
# {'symbol': 'ICNETH', 'price': '0.00166300'}
# {'symbol': 'MCOBTC', 'price': '0.00021140'}
# {'symbol': 'WTCBTC', 'price': '0.00002913'}
# {'symbol': 'WTCETH', 'price': '0.00023700'}
# ...

# %%
q_list = str.split(MIN_WITHDRAWAL_QUANTITY, "|")

currency_min_withdral_quantity = dict()

print(type(q_list))
for q in q_list:
    c_list = q.strip().split(":")
    currency_min_withdral_quantity[c_list[0].strip()] = float(c_list[1].strip())

for k,v in currency_min_withdral_quantity.items():
    print("k={}, v={}".format(k, v))
# Out:
# <class 'list'>
# k=BTC, v=0.002
# k=ETH, v=0.01
# k=LTC, v=0.1
# k=ETC, v=0.1
# k=XRP, v=21.0
# k=BCH, v=0.002
# k=BTG, v=0.002
# k=EOS, v=0.5
# k=ICX, v=4.0
# k=TRX, v=150.0
# k=ELF, v=10.0
# k=OMG, v=2.0
# k=GLM, v=30.0
# k=ZIL, v=30.0
# k=POWR, v=23.0
# k=LRC, v=42.0
# k=EOSDAC, v=10.0
# k=STEEM, v=0.01
# k=STRAX, v=0.2
# k=ZRX, v=6.0
# k=REP, v=0.08
# k=XEM, v=4.0
# k=SNT, v=23.0
# k=ADA, v=1.0
# k=BAT, v=3.0
# k=WTC, v=1.4
# k=LOOM, v=22.0
# k=WAVES, v=2.0
# k=TRUE, v=10.0
# k=LINK, v=0.11
# k=MEETONE, v=10.0
# k=HORUS, v=10.0
# k=ADD, v=100.0
# k=RNT, v=300.0
# k=ENJ, v=2.0
# k=VET, v=200.0
# k=MTL, v=0.9
# k=CHL, v=100.0
# k=BLACK, v=10.0
# k=ATD, v=100.0
# k=IOST, v=1000.0
# k=TMTG, v=360.0
# k=QKC, v=2000.0
# k=HDAC, v=200.0
# k=WET, v=840.0
# k=AMO, v=7000.0
# k=BSV, v=0.002
# k=BXA, v=15.0
# k=DAC, v=670.0
# k=ORBS, v=24.0
# k=TFUEL, v=10.0
# k=VALOR, v=5.0
# k=CON, v=460.0
# k=ANKR, v=27.0
# k=MIX, v=360.0
# k=LAMB, v=40.0
# k=CRO, v=17.0
# k=FX, v=10.0
# k=CHR, v=12.0
# ...

# %%
from util import http_util
import json

available = 1

def get_asset_status(coin):
    url = "https://api.bithumb.com/public/assetsstatus/{}".format(coin)
    """
    获取资产的状态信息：https://apidocs.bithumb.com/docs/assets_status
    https://api.bithumb.com/public/assetsstatus/{order_currency}
    :param coin: 币
    :return:
    传入的币的状态
    {
    "status" : "0000",
    "data" :
    [
        {
            "deposit_status" : 1,
            "withdrawal_status" : 0
        }
    ]
    }
    """
    response = http_util.get(url)
    body = json.loads(response.text)
    print(body)
    data = body["data"]
    print(data)
    return data["deposit_status"] == available, data["withdrawal_status"] == available


get_asset_status("BTC")
# Out:
# {'status': '0000', 'data': {'withdrawal_status': 1, 'deposit_status': 1}}
# {'withdrawal_status': 1, 'deposit_status': 1}
# (True, True)

# %%
from
